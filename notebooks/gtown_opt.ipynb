# %%
import pandas as pd


df = pd.read_csv('raw_data.csv')
df
# Out:
#               name  min  sec  plus_minus
# 0   Blake Buchanan   26   17           2
# 1     Jalen Warley   16    7           0
# 2  Elijah Saunders   34   31         -13
# 3   Isaac McKneely   29   48         -11
# 4         TJ Power   21    7         -18
# 5      Jacob Cofie   15   45           3
# 6     Andrew Rohde   23   53         -11
# 7     Dai Dai Ames   21   37         -11
# 8     Taine Murray    6   59           1
# 9     Ishan Sharma    0   57           3

# %%
# Clean data
df["name_lower"] = df["name"].str.lower().apply(lambda x: "_".join(x.split()))

# Convert time to minutes
df["time"] = df["min"] + df["sec"] / 60

# Round so that numbers add up to 200
while True:
    df["round_time"] = df["time"].round(0).astype(int)
    if df["round_time"].sum() == 200:
        break
    elif df["round_time"].sum() < 200:
        df["time"] = df["time"] * 1.01
    else:
        df["time"] = df["time"] * 0.99

# Set allowed positions
df["allowed_positions"] = [
    "5",
    "1_3",
    "3_4_5",
    "2",
    "3_4",
    "4_5",
    "1_2_3",
    "1",
    "2_3",
    "2_3",
]

df
# Out:
#               name  min  sec  plus_minus       name_lower       time  \
# 0   Blake Buchanan   26   17           2   blake_buchanan  26.811628
# 1     Jalen Warley   16    7           0     jalen_warley  16.440612
# 2  Elijah Saunders   34   31         -13  elijah_saunders  35.210452
# 3   Isaac McKneely   29   48         -11   isaac_mckneely  30.398980
# 4         TJ Power   21    7         -18         tj_power  21.541112
# 5      Jacob Cofie   15   45           3      jacob_cofie  16.066575
# 6     Andrew Rohde   23   53         -11     andrew_rohde  24.363388
# 7     Dai Dai Ames   21   37         -11     dai_dai_ames  22.051162
# 8     Taine Murray    6   59           1     taine_murray   7.123698
# 9     Ishan Sharma    0   57           3     ishan_sharma   0.969095
#
#    round_time allowed_positions
# 0          27                 5
# 1          16               1_3
# 2          35             3_4_5
# 3          30                 2
# 4          22               3_4
# 5          16               4_5
# 6          24             1_2_3
# 7          22                 1
# 8           7               2_3
# 9           1               2_3

# %%
import numpy as np
from pulp import (
    LpProblem,
    LpVariable,
    lpSum,
    LpInteger,
    LpMinimize,
    LpStatus,
    value,
    PULP_CBC_CMD,
)
import random

# Create binary variables
PLAYERS = df["name_lower"].tolist()
MINS = range(1, 41)
POS = range(1, 6)


def extract_lineup(min: int, choices: dict, pm: dict):
    row = {"min": min}
    for pos in POS:
        for player in PLAYERS:
            if value(choices[player][min][pos]) == 1:
                row[pos] = player
    row["plus_minus"] = value(pm[min])
    return row


def run_opt(seed: int):
    # Create the problem
    prob = LpProblem("gtown_optimize", LpMinimize)

    # choice_<player>_<min>_<pos>
    # E.g., choice_john_doe_1_1 is 1 if John Doe is on the court in minute 1 in position 1
    choices = LpVariable.dicts("choice", (PLAYERS, MINS, POS), cat="Binary")

    # Add plus minus variables
    pm = LpVariable.dicts("pm", (MINS), -10, 10, LpInteger)

    abs_min_changes = LpVariable.dicts("abs_min_changes", (range(1, 40)), lowBound=0)

    # Add a small random coefficient to each choice variable
    random.seed(seed)
    random_coefficients = {}
    for player in PLAYERS:
        for min in MINS:
            for pos in POS:
                # Generate a small random number, e.g., between 0 and 1e-6
                random_coefficients[(player, min, pos)] = random.uniform(0, 1e-6)
                # You can store or print these coefficients if needed

    random_term = lpSum(
        [
            random_coefficients[(player, min, pos)] * choices[player][min][pos]
            for player in PLAYERS
            for min in MINS
            for pos in POS
        ]
    )

    prob += random_term, "sum_random"

    # Set constraints

    # Each player can only be in one position per minute
    for player in PLAYERS:
        for min in MINS:
            prob += lpSum([choices[player][min][pos] for pos in POS]) <= 1

    # Exactly one player per position per minute
    for min in MINS:
        for pos in POS:
            prob += lpSum([choices[player][min][pos] for player in PLAYERS]) == 1
            for player in PLAYERS:
                if min < 40:
                    prob += (
                        abs_min_changes[min]
                        >= choices[player][min + 1][pos] - choices[player][min][pos]
                    )

    for player in PLAYERS:
        # Player minutes have to match data
        total_min = df.loc[df["name_lower"] == player, "round_time"].iloc[0]
        prob += (
            lpSum([choices[player][min][pos] for min in MINS for pos in POS])
            == total_min
        )

        # Set specific player position constraints
        allowed_positions = (
            df.loc[df["name_lower"] == player, "allowed_positions"].iloc[0].split("_")
        )
        for pos in POS:
            if str(pos) not in allowed_positions:
                prob += lpSum([choices[player][min][pos] for min in MINS]) == 0

        # Set plus minus constraint
        player_pm = df.loc[df["name_lower"] == player, "plus_minus"].iloc[0]

        # Create binary variables to track if player is on court each minute
        on_court = LpVariable.dicts(f"on_court_{player}", MINS, cat="Binary")

        # Create variables for player's contribution to plus-minus each minute
        player_pm_per_min = LpVariable.dicts(
            f"pm_{player}", MINS, None, None, LpInteger
        )

        # Link on_court variable to choices
        for min in MINS:
            # Track if player is on court
            prob += on_court[min] == lpSum([choices[player][min][pos] for pos in POS])

            # If player is on court (on_court[min] = 1), then player_pm_per_min[min] = pm[min]
            # If player is off court (on_court[min] = 0), then player_pm_per_min[min] = 0
            M = 100  # A large number that's bigger than any possible plus-minus value
            prob += player_pm_per_min[min] <= pm[min] + M * (1 - on_court[min])
            prob += player_pm_per_min[min] >= pm[min] - M * (1 - on_court[min])
            prob += player_pm_per_min[min] <= M * on_court[min]
            prob += player_pm_per_min[min] >= -M * on_court[min]

        # Sum of player's plus-minus contributions must equal their total plus-minus
        prob += lpSum([player_pm_per_min[min] for min in MINS]) == player_pm

    # Overall plus minus constraint
    prob += lpSum([pm[min] for min in MINS]) == -11

    # Write the problem
    prob.writeLP("gtown_optimize.lp")

    # Solve
    prob.solve(
        PULP_CBC_CMD(
            msg=True,
            timeLimit=10,  # Allow up to 5 minutes
        )
    )

    print("Status:", LpStatus[prob.status])
    print(prob.objective.value())

    rows = []
    for min in MINS:
        rows.append(extract_lineup(min, choices, pm))

    if prob.status != 1:
        return None
    else:
        return pd.DataFrame(rows)

# %%
from tqdm import tqdm


all_lineup_dfs = []
tt = 23
for i in tqdm(range(tt, tt + 1)):
    lineup_df = run_opt(i)
    if lineup_df is not None:
        all_lineup_dfs.append(lineup_df.assign(seed=i))
    else:
        print(f"Failed on seed {i}")

lineup_df = pd.concat(all_lineup_dfs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
lineup_df
# Out:
#     min             1               2                3                4  \
# 0     1  dai_dai_ames  isaac_mckneely     andrew_rohde         tj_power
# 1     2  dai_dai_ames    andrew_rohde  elijah_saunders      jacob_cofie
# 2     3  dai_dai_ames  isaac_mckneely     jalen_warley         tj_power
# 3     4  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 4     5  andrew_rohde  isaac_mckneely     jalen_warley  elijah_saunders
# 5     6  dai_dai_ames  isaac_mckneely  elijah_saunders      jacob_cofie
# 6     7  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 7     8  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 8     9  jalen_warley  isaac_mckneely     andrew_rohde      jacob_cofie
# 9    10  dai_dai_ames  isaac_mckneely     jalen_warley      jacob_cofie
# 10   11  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 11   12  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 12   13  dai_dai_ames  isaac_mckneely     taine_murray  elijah_saunders
# 13   14  andrew_rohde    taine_murray     jalen_warley  elijah_saunders
# 14   15  dai_dai_ames    andrew_rohde     taine_murray         tj_power
# 15   16  dai_dai_ames  isaac_mckneely  elijah_saunders         tj_power
# 16   17  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 17   18  jalen_warley    ishan_sharma  elijah_saunders      jacob_cofie
# 18   19  dai_dai_ames    andrew_rohde  elijah_saunders         tj_power
# 19   20  jalen_warley    andrew_rohde         tj_power  elijah_saunders
# 20   21  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 21   22  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 22   23  dai_dai_ames  isaac_mckneely     jalen_warley         tj_power
# 23   24  jalen_warley    taine_murray  elijah_saunders      jacob_cofie
# 24   25  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 25   26  andrew_rohde  isaac_mckneely  elijah_saunders         tj_power
# 26   27  dai_dai_ames  isaac_mckneely     andrew_rohde         tj_power
# 27   28  dai_dai_ames    taine_murray     jalen_warley         tj_power
# 28   29  andrew_rohde  isaac_mckneely  elijah_saunders      jacob_cofie
# 29   30  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 30   31  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 31   32  andrew_rohde  isaac_mckneely  elijah_saunders         tj_power
# 32   33  dai_dai_ames  isaac_mckneely     taine_murray  elijah_saunders
# 33   34  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 34   35  andrew_rohde  isaac_mckneely         tj_power      jacob_cofie
# 35   36  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 36   37  jalen_warley  isaac_mckneely     andrew_rohde  elijah_saunders
# 37   38  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 38   39  andrew_rohde    taine_murray     jalen_warley         tj_power
# 39   40  jalen_warley    andrew_rohde         tj_power  elijah_saunders
#
#                   5  plus_minus  seed
# 0    blake_buchanan        -3.0    23
# 1    blake_buchanan         0.0    23
# 2   elijah_saunders        -3.0    23
# 3    blake_buchanan        -3.0    23
# 4       jacob_cofie         2.0    23
# 5    blake_buchanan         3.0    23
# 6    blake_buchanan        -3.0    23
# 7    blake_buchanan         3.0    23
# 8    blake_buchanan         3.0    23
# 9   elijah_saunders        -3.0    23
# 10   blake_buchanan         3.0    23
# 11   blake_buchanan         3.0    23
# 12   blake_buchanan        -3.0    23
# 13      jacob_cofie         3.0    23
# 14   blake_buchanan        -2.0    23
# 15   blake_buchanan         3.0    23
# 16      jacob_cofie         0.0    23
# 17   blake_buchanan         3.0    23
# 18      jacob_cofie        -3.0    23
# 19      jacob_cofie        -3.0    23
# 20   blake_buchanan        -3.0    23
# 21   blake_buchanan        -3.0    23
# 22  elijah_saunders        -2.0    23
# 23   blake_buchanan         2.0    23
# 24   blake_buchanan        -3.0    23
# 25      jacob_cofie        -3.0    23
# 26  elijah_saunders         3.0    23
# 27   blake_buchanan         3.0    23
# 28   blake_buchanan        -1.0    23
# 29      jacob_cofie         1.0    23
# 30   blake_buchanan        -1.0    23
# 31   blake_buchanan        -3.0    23
# 32   blake_buchanan         1.0    23
# 33   blake_buchanan         3.0    23
# 34   blake_buchanan         1.0    23
# 35   blake_buchanan        -1.0    23
# 36   blake_buchanan         0.0    23
# 37      jacob_cofie        -2.0    23
# 38  elijah_saunders        -3.0    23
# 39   blake_buchanan         0.0    23

# %%
lineup_df
# Out:
#     min             1               2                3                4  \
# 0     1  dai_dai_ames    ishan_sharma  elijah_saunders      jacob_cofie
# 1     2  dai_dai_ames  isaac_mckneely     jalen_warley         tj_power
# 2     3  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 3     4  dai_dai_ames  isaac_mckneely     taine_murray  elijah_saunders
# 4     5  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# ..  ...           ...             ...              ...              ...
# 35   36  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 36   37  andrew_rohde    taine_murray         tj_power  elijah_saunders
# 37   38  dai_dai_ames    taine_murray     jalen_warley  elijah_saunders
# 38   39  jalen_warley  isaac_mckneely     andrew_rohde  elijah_saunders
# 39   40  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
#
#                  5  plus_minus  seed
# 0   blake_buchanan         3.0     1
# 1      jacob_cofie        -1.0     1
# 2      jacob_cofie         3.0     1
# 3   blake_buchanan        -3.0     1
# 4   blake_buchanan        -3.0     1
# ..             ...         ...   ...
# 35  blake_buchanan        -3.0    99
# 36  blake_buchanan        -3.0    99
# 37  blake_buchanan        -3.0    99
# 38  blake_buchanan         3.0    99
# 39     jacob_cofie         0.0    99
#
# [2640 rows x 8 columns]

# %%
long = lineup_df.melt(id_vars=["min", "plus_minus", "seed"], value_vars=list(POS), var_name="position", value_name="player")

# Fill in missing values
long["minutes"] = 1
all_vals = long[["position", "player"]].drop_duplicates()
all_vals["minutes"] = 0
all_vals["plus_minus"] = 0
all_vals = pd.concat([all_vals.assign(seed=seed) for seed in lineup_df.seed.unique()], ignore_index=True)
long = pd.concat([long, all_vals], ignore_index=True)

tmp = long.groupby(["position", "seed", "player"]).agg(
    minutes=("minutes", "sum"),
    plus_minus=("plus_minus", "sum"),
).reset_index()
tmp["plus_minus"] = tmp["plus_minus"].astype(int)
tmp2 = tmp.groupby(["position", "player"]).agg(
    min_minutes=("minutes", "min"),
    max_minutes=("minutes", "max"),
    avg_minutes=("minutes", "mean"),
    pct5_minutes=("minutes", lambda x: x.quantile(0.05)),
    pct95_minutes=("minutes", lambda x: x.quantile(0.95)),
    min_plus_minus=("plus_minus", "min"),
    max_plus_minus=("plus_minus", "max"),
    avg_plus_minus=("plus_minus", "mean"),
    pct5_plus_minus=("plus_minus", lambda x: x.quantile(0.05)),
    pct95_plus_minus=("plus_minus", lambda x: x.quantile(0.95)),
).reset_index().sort_values(["player", "position"])
display(tmp2)
# Out:
#     position           player  min_minutes  max_minutes  avg_minutes  \
# 0          1     andrew_rohde            7           13    10.166667
# 3          2     andrew_rohde            3            7     5.181818
# 7          3     andrew_rohde            5           12     8.651515
# 16         5   blake_buchanan           27           27    27.000000
# 1          1     dai_dai_ames           22           22    22.000000
# 8          3  elijah_saunders            3           13     9.772727
# 13         4  elijah_saunders           15           29    20.333333
# 17         5  elijah_saunders            3            7     4.893939
# 4          2   isaac_mckneely           30           30    30.000000
# 5          2     ishan_sharma            0            1     0.939394
# 9          3     ishan_sharma            0            1     0.060606
# 14         4      jacob_cofie            6           10     7.893939
# 18         5      jacob_cofie            6           10     8.106061
# 2          1     jalen_warley            5           11     7.833333
# 10         3     jalen_warley            5           11     8.166667
# 6          2     taine_murray            2            6     3.878788
# 11         3     taine_murray            1            5     3.121212
# 12         3         tj_power            7           17    10.227273
# 15         4         tj_power            5           15    11.772727
#
#     pct5_minutes  pct95_minutes  min_plus_minus  max_plus_minus  \
# 0           8.00          12.00             -14               7
# 3           4.25           7.00             -13               3
# 7           6.00          11.00             -15              10
# 16         27.00          27.00               2               2
# 1          22.00          22.00             -11             -11
# 8           5.00          12.00             -16              12
# 13         18.00          26.75             -21               8
# 17          3.00           6.00             -17               3
# 4          30.00          30.00             -11             -11
# 5           0.25           1.00               0               3
# 9           0.00           0.75               0               3
# 14          6.00           9.00              -1              19
# 18          7.00          10.00             -16               4
# 2           6.00          10.00              -7              14
# 10          6.00          10.00             -14               7
# 6           3.00           4.75              -5              10
# 11          2.25           4.00              -9               6
# 12          8.00          15.00             -16              12
# 15          7.00          14.00             -30              -2
#
#     avg_plus_minus  pct5_plus_minus  pct95_plus_minus
# 0        -2.106061            -9.00              4.75
# 3        -3.787879            -9.00              1.00
# 7        -5.106061           -12.00              2.75
# 16        2.000000             2.00              2.00
# 1       -11.000000           -11.00            -11.00
# 8        -0.469697            -8.75              9.00
# 13       -7.030303           -17.75              4.75
# 17       -5.500000           -11.75              0.00
# 4       -11.000000           -11.00            -11.00
# 5         2.818182             0.75              3.00
# 9         0.181818             0.00              2.25
# 14       10.500000             4.25             16.00
# 18       -7.500000           -13.00             -1.25
# 2         2.106061            -4.75              9.00
# 10       -2.106061            -9.00              4.75
# 6         0.969697            -4.00              6.00
# 11        0.030303            -5.00              5.00
# 12       -3.530303           -13.00              4.75
# 15      -14.469697           -22.75             -5.00

# %%
tmp.query("player == 'elijah_saunders' & position == 3 & minutes == 3")
# Out:
#      position  seed           player  minutes  plus_minus
# 673         3    52  elijah_saunders        3           3

# %%
tmp.query("seed == 52")
# Out:
#       position  seed           player  minutes  plus_minus
# 105          1    52     andrew_rohde       11          -9
# 106          1    52     dai_dai_ames       22         -11
# 107          1    52     jalen_warley        7           9
# 338          2    52     andrew_rohde        7           0
# 339          2    52   isaac_mckneely       30         -11
# 340          2    52     ishan_sharma        1           3
# 341          2    52     taine_murray        2          -3
# 672          3    52     andrew_rohde        6          -2
# 673          3    52  elijah_saunders        3           3
# 674          3    52     ishan_sharma        0           0
# 675          3    52     jalen_warley        9          -9
# 676          3    52     taine_murray        5           4
# 677          3    52         tj_power       17          -7
# 963          4    52  elijah_saunders       29         -13
# 964          4    52      jacob_cofie        6          13
# 965          4    52         tj_power        5         -11
# 1161         5    52   blake_buchanan       27           2
# 1162         5    52  elijah_saunders        3          -3
# 1163         5    52      jacob_cofie       10         -10

# %%
lineup_df.query("seed == 52")
# Out:
#     min             1               2                3                4  \
# 0     1  jalen_warley    ishan_sharma         tj_power  elijah_saunders
# 1     2  dai_dai_ames    taine_murray     jalen_warley         tj_power
# 2     3  dai_dai_ames  isaac_mckneely     andrew_rohde         tj_power
# 3     4  dai_dai_ames  isaac_mckneely     taine_murray         tj_power
# 4     5  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 5     6  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 6     7  dai_dai_ames  isaac_mckneely     jalen_warley      jacob_cofie
# 7     8  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 8     9  dai_dai_ames    taine_murray     andrew_rohde  elijah_saunders
# 9    10  andrew_rohde  isaac_mckneely     taine_murray  elijah_saunders
# 10   11  dai_dai_ames    andrew_rohde     jalen_warley      jacob_cofie
# 11   12  andrew_rohde  isaac_mckneely     jalen_warley  elijah_saunders
# 12   13  dai_dai_ames    andrew_rohde  elijah_saunders      jacob_cofie
# 13   14  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 14   15  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 15   16  dai_dai_ames    andrew_rohde     jalen_warley  elijah_saunders
# 16   17  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 17   18  dai_dai_ames    andrew_rohde         tj_power      jacob_cofie
# 18   19  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 19   20  andrew_rohde  isaac_mckneely     jalen_warley  elijah_saunders
# 20   21  dai_dai_ames    andrew_rohde         tj_power  elijah_saunders
# 21   22  andrew_rohde  isaac_mckneely  elijah_saunders         tj_power
# 22   23  dai_dai_ames    andrew_rohde     jalen_warley         tj_power
# 23   24  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 24   25  jalen_warley  isaac_mckneely     taine_murray  elijah_saunders
# 25   26  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 26   27  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 27   28  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 28   29  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 29   30  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 30   31  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 31   32  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 32   33  jalen_warley    andrew_rohde         tj_power  elijah_saunders
# 33   34  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 34   35  andrew_rohde  isaac_mckneely     taine_murray  elijah_saunders
# 35   36  dai_dai_ames  isaac_mckneely     taine_murray  elijah_saunders
# 36   37  andrew_rohde  isaac_mckneely  elijah_saunders      jacob_cofie
# 37   38  dai_dai_ames  isaac_mckneely     jalen_warley      jacob_cofie
# 38   39  jalen_warley  isaac_mckneely     andrew_rohde  elijah_saunders
# 39   40  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
#
#                   5  plus_minus  seed
# 0    blake_buchanan         3.0    52
# 1       jacob_cofie        -3.0    52
# 2       jacob_cofie         0.0    52
# 3   elijah_saunders        -3.0    52
# 4    blake_buchanan        -2.0    52
# 5    blake_buchanan         3.0    52
# 6    blake_buchanan         3.0    52
# 7    blake_buchanan        -3.0    52
# 8    blake_buchanan         0.0    52
# 9    blake_buchanan         3.0    52
# 10   blake_buchanan         3.0    52
# 11   blake_buchanan        -3.0    52
# 12   blake_buchanan         3.0    52
# 13   blake_buchanan         3.0    52
# 14   blake_buchanan        -3.0    52
# 15      jacob_cofie        -3.0    52
# 16   blake_buchanan        -3.0    52
# 17   blake_buchanan        -1.0    52
# 18      jacob_cofie         2.0    52
# 19   blake_buchanan        -3.0    52
# 20      jacob_cofie        -3.0    52
# 21      jacob_cofie        -3.0    52
# 22  elijah_saunders        -2.0    52
# 23   blake_buchanan         1.0    52
# 24      jacob_cofie         3.0    52
# 25      jacob_cofie        -3.0    52
# 26      jacob_cofie         3.0    52
# 27   blake_buchanan         3.0    52
# 28   blake_buchanan        -3.0    52
# 29   blake_buchanan         3.0    52
# 30   blake_buchanan        -3.0    52
# 31   blake_buchanan        -3.0    52
# 32   blake_buchanan         3.0    52
# 33   blake_buchanan        -3.0    52
# 34   blake_buchanan        -2.0    52
# 35   blake_buchanan         3.0    52
# 36   blake_buchanan         3.0    52
# 37  elijah_saunders         2.0    52
# 38   blake_buchanan        -3.0    52
# 39      jacob_cofie        -3.0    52

# %%
tmp2.to_csv("solution.csv", index=False)
