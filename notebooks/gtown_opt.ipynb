# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from secret_scrimmage_lineup_guesser.data_processing import clean_data

df = pd.read_csv('../data/raw_data.csv')

# Defines who can play which positions, and who gets preferences for which position
position_preferences = {
    1: ["dai_dai_ames", "jalen_warley", "andrew_rohde"],
    2: ["isaac_mckneely", "andrew_rohde", "ishan_sharma", "taine_murray"],
    3: ["taine_murray", "ishan_sharma", "andrew_rohde", "jalen_warley", "tj_power", "elijah_saunders"],
    4: ["elijah_saunders", "tj_power", "jacob_cofie"],
    5: ["blake_buchanan", "jacob_cofie", "elijah_saunders"],
}
df = clean_data(df)
df
# Out:
#               name  min  sec  plus_minus       name_lower       time  \
# 0   Blake Buchanan   26   17           2   blake_buchanan  26.811628
# 1     Jalen Warley   16    7           0     jalen_warley  16.440612
# 2  Elijah Saunders   34   31         -13  elijah_saunders  35.210452
# 3   Isaac McKneely   29   48         -11   isaac_mckneely  30.398980
# 4         TJ Power   21    7         -18         tj_power  21.541112
# 5      Jacob Cofie   15   45           3      jacob_cofie  16.066575
# 6     Andrew Rohde   23   53         -11     andrew_rohde  24.363388
# 7     Dai Dai Ames   21   37         -11     dai_dai_ames  22.051162
# 8     Taine Murray    6   59           1     taine_murray   7.123698
# 9     Ishan Sharma    0   57           3     ishan_sharma   0.969095
#
#    round_time
# 0          27
# 1          16
# 2          35
# 3          30
# 4          22
# 5          16
# 6          24
# 7          22
# 8           7
# 9           1

# %%
import pandas as pd
from itertools import product
from typing import List, Dict
from collections import defaultdict

def generate_all_valid_lineups(
    position_preferences: Dict[int, List[str]]
) -> List[Dict[int, str]]:
    """
    Generate all possible lineups based on position preferences.

    Args:
        position_preferences (dict): A dictionary where keys are positions (1-5) and values are
                                     lists of players ordered by preference for that position.

    Returns:
        List[Dict[int, str]]: A list of dictionaries, each representing a valid lineup where keys
                              are positions and values are player names.
    """
    def backtrack(position: int, current_lineup: Dict[int, str], used_players: set, all_lineups: List[Dict[int, str]]):
        if position > 5:
            # All positions have been assigned
            all_lineups.append(current_lineup.copy())
            return
        
        for player in position_preferences.get(position, []):
            if player not in used_players:
                current_lineup[position] = player
                used_players.add(player)
                
                backtrack(position + 1, current_lineup, used_players, all_lineups)
                
                # Backtrack
                used_players.remove(player)
                del current_lineup[position]
    
    all_lineups = []
    backtrack(1, {}, set(), all_lineups)
    return all_lineups

def get_invalid_pairs(lineups: List[Dict[int, str]], position_preferences: Dict[int, List[str]]) -> List[Dict[int, str]]:
    """
    Filter lineups to ensure that no player is assigned in a way that violates the
    preference hierarchy across different positions.

    Args:
        lineups (List[Dict[int, str]]): List of generated lineups to be filtered.
        position_preferences (dict): Position preferences as defined earlier.

    Returns:
        List[Dict[int, str]]: Filtered list of valid lineups respecting preference hierarchy.
    """
    # Create a player to preferences mapping for quick lookup
    player_preferences = defaultdict(dict)
    for pos, players in position_preferences.items():
        for rank, player in enumerate(players):
            player_preferences[player][pos] = rank
    
    invalid_pairs = []
    for lineup in lineups:
        for pos1, player1 in lineup.items():
            for pos2, player2 in lineup.items():
                if pos1 <= pos2:
                    continue
                # Mark invalid if player1 preferred over player2 for pos2 and vice versa
                pref11 = player_preferences[player1].get(pos1, float('inf'))
                pref12 = player_preferences[player1].get(pos2, float('inf'))
                pref21 = player_preferences[player2].get(pos1, float('inf'))
                pref22 = player_preferences[player2].get(pos2, float('inf'))
                if pref11 > pref21 and pref12 < pref22:
                    invalid_pairs.append(((player1, pos1), (player2, pos2)))
    return list(set(invalid_pairs))

position_preferences = {
    1: ["dai_dai_ames", "jalen_warley", "andrew_rohde"],
    2: ["isaac_mckneely", "andrew_rohde", "ishan_sharma", "taine_murray"],
    3: ["taine_murray", "ishan_sharma", "andrew_rohde", "jalen_warley", "tj_power", "elijah_saunders"],
    4: ["elijah_saunders", "tj_power", "jacob_cofie"],
    5: ["blake_buchanan", "jacob_cofie", "elijah_saunders"],
}

all_lineups = generate_all_valid_lineups(position_preferences)
invalid_pairs = get_invalid_pairs(all_lineups, position_preferences)

# %%
invalid_pairs
# Out:
# [(('andrew_rohde', 3), ('taine_murray', 2)),
#  (('ishan_sharma', 3), ('taine_murray', 2)),
#  (('andrew_rohde', 3), ('ishan_sharma', 2)),
#  (('tj_power', 4), ('elijah_saunders', 3)),
#  (('elijah_saunders', 5), ('jacob_cofie', 4)),
#  (('jalen_warley', 3), ('andrew_rohde', 1))]

# %%
from secret_scrimmage_lineup_guesser.optimization import run_opt

lineup_df = run_opt(df, position_preferences, invalid_pairs, overall_pm=-11, time_limit=100)
lineup_df
# Out:
#     min             1               2                3                4  \
# 0     1  jalen_warley  isaac_mckneely  elijah_saunders      jacob_cofie
# 1     2  jalen_warley  isaac_mckneely     andrew_rohde  elijah_saunders
# 2     3  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 3     4  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 4     5  dai_dai_ames  isaac_mckneely     andrew_rohde         tj_power
# 5     6  jalen_warley    ishan_sharma         tj_power  elijah_saunders
# 6     7  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 7     8  dai_dai_ames  isaac_mckneely     jalen_warley         tj_power
# 8     9  andrew_rohde  isaac_mckneely     taine_murray  elijah_saunders
# 9    10  dai_dai_ames    andrew_rohde  elijah_saunders      jacob_cofie
# 10   11  dai_dai_ames    andrew_rohde     taine_murray         tj_power
# 11   12  jalen_warley  isaac_mckneely     andrew_rohde         tj_power
# 12   13  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 13   14  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 14   15  dai_dai_ames  isaac_mckneely     andrew_rohde         tj_power
# 15   16  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 16   17  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 17   18  jalen_warley    andrew_rohde  elijah_saunders      jacob_cofie
# 18   19  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 19   20  andrew_rohde  isaac_mckneely  elijah_saunders      jacob_cofie
# 20   21  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 21   22  andrew_rohde    taine_murray         tj_power  elijah_saunders
# 22   23  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 23   24  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 24   25  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
# 25   26  jalen_warley    andrew_rohde     taine_murray      jacob_cofie
# 26   27  dai_dai_ames    andrew_rohde         tj_power  elijah_saunders
# 27   28  dai_dai_ames    andrew_rohde         tj_power      jacob_cofie
# 28   29  dai_dai_ames  isaac_mckneely     taine_murray         tj_power
# 29   30  dai_dai_ames  isaac_mckneely     jalen_warley  elijah_saunders
# 30   31  andrew_rohde  isaac_mckneely         tj_power  elijah_saunders
# 31   32  jalen_warley  isaac_mckneely     andrew_rohde  elijah_saunders
# 32   33  andrew_rohde  isaac_mckneely  elijah_saunders      jacob_cofie
# 33   34  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 34   35  dai_dai_ames    andrew_rohde     jalen_warley  elijah_saunders
# 35   36  dai_dai_ames  isaac_mckneely         tj_power  elijah_saunders
# 36   37  dai_dai_ames    taine_murray     jalen_warley  elijah_saunders
# 37   38  dai_dai_ames  isaac_mckneely     taine_murray         tj_power
# 38   39  dai_dai_ames  isaac_mckneely     andrew_rohde  elijah_saunders
# 39   40  jalen_warley  isaac_mckneely         tj_power  elijah_saunders
#
#                   5  plus_minus
# 0    blake_buchanan         2.0
# 1    blake_buchanan         3.0
# 2       jacob_cofie        -3.0
# 3       jacob_cofie         3.0
# 4   elijah_saunders        -3.0
# 5    blake_buchanan         3.0
# 6    blake_buchanan         3.0
# 7    blake_buchanan        -3.0
# 8       jacob_cofie        -3.0
# 9    blake_buchanan         3.0
# 10  elijah_saunders         3.0
# 11  elijah_saunders        -3.0
# 12   blake_buchanan        -3.0
# 13   blake_buchanan        -3.0
# 14  elijah_saunders        -3.0
# 15   blake_buchanan        -3.0
# 16   blake_buchanan         3.0
# 17   blake_buchanan        -3.0
# 18   blake_buchanan        -3.0
# 19   blake_buchanan         3.0
# 20      jacob_cofie        -3.0
# 21   blake_buchanan        -2.0
# 22   blake_buchanan        -1.0
# 23      jacob_cofie        -3.0
# 24   blake_buchanan         2.0
# 25   blake_buchanan         3.0
# 26   blake_buchanan        -3.0
# 27   blake_buchanan        -1.0
# 28      jacob_cofie         3.0
# 29   blake_buchanan         3.0
# 30   blake_buchanan         3.0
# 31      jacob_cofie         2.0
# 32   blake_buchanan         3.0
# 33   blake_buchanan         2.0
# 34   blake_buchanan         0.0
# 35   blake_buchanan        -3.0
# 36      jacob_cofie        -3.0
# 37      jacob_cofie         0.0
# 38   blake_buchanan        -3.0
# 39   blake_buchanan        -3.0

# %%
from secret_scrimmage_lineup_guesser.optimization import get_positional_min_max

results = get_positional_min_max(df, position_preferences, invalid_pairs, overall_pm=-11, time_limit=10)
display(results)
# Out:
# 100%|██████████| 10/10 [02:55<00:00, 17.58s/it]
#             player     1     2     3     4     5
# 0   blake_buchanan     0     0     0     0    27
# 1     jalen_warley  0-16     0  0-16     0     0
# 2  elijah_saunders     0     0  3-16  6-31  3-13
# 3   isaac_mckneely     0    30     0     0     0
# 4         tj_power     0     0  4-17  5-16     0
# 5      jacob_cofie     0     0     0  5-16  0-11
# 6     andrew_rohde  2-18  2-10  0-20     0     0
# 7     dai_dai_ames    22     0     0     0     0
# 8     taine_murray     0   0-4   0-7     0     0
# 9     ishan_sharma     0   0-1   0-1     0     0

# %%
tmp1 = run_opt(
    df,
    position_preferences,
    invalid_pairs,
    overall_pm=-11,
    time_limit=10,
    objective=("jacob_cofie", 5, True),
)
tmp2 = run_opt(
    df,
    position_preferences,
    invalid_pairs,
    overall_pm=-11,
    time_limit=10,
    objective=("jacob_cofie", 5, False),
)

# %%
for i, tmp in enumerate([tmp1, tmp2]):
    print(f"Cofie only/mostly played at the {i+4}:")

    cofie = (tmp[4] == "jacob_cofie") | (tmp[5] == "jacob_cofie")
    buchanan = tmp[5] == "blake_buchanan"
    saunders = (
        (tmp[4] == "elijah_saunders")
        | (tmp[5] == "elijah_saunders")
        | (tmp[3] == "elijah_saunders")
    )

    # Create all possible combinations of the three boolean arrays
    combinations = [
        (~cofie & ~buchanan & ~saunders, "None"),
        (cofie & ~buchanan & ~saunders, "Only Cofie"),
        (~cofie & buchanan & ~saunders, "Only Buchanan"),
        (~cofie & ~buchanan & saunders, "Only Saunders"),
        (cofie & buchanan & ~saunders, "Cofie & Buchanan"),
        (cofie & ~buchanan & saunders, "Cofie & Saunders"),
        (~cofie & buchanan & saunders, "Buchanan & Saunders"),
        (cofie & buchanan & saunders, "All three"),
    ]

    for mask, label in combinations:
        filtered = tmp[mask]
        if len(filtered) > 0:
            print(f"\n{label}:")
            print(f"Minutes: {len(filtered)}")
            print(f"Plus/minus: {filtered['plus_minus'].sum()}")
    print("\n\n")
# Out:
# Cofie only/mostly played at the 4:
#
# Only Saunders:
# Minutes: 13
# Plus/minus: -13.0
#
# Cofie & Buchanan:
# Minutes: 5
# Plus/minus: 2.0
#
# Buchanan & Saunders:
# Minutes: 11
# Plus/minus: -1.0
#
# All three:
# Minutes: 11
# Plus/minus: 1.0
#
#
#
# Cofie only/mostly played at the 5:
#
# Only Cofie:
# Minutes: 3
# Plus/minus: 1.0
#
# Only Saunders:
# Minutes: 2
# Plus/minus: -6.0
#
# Cofie & Buchanan:
# Minutes: 2
# Plus/minus: 1.0
#
# Cofie & Saunders:
# Minutes: 8
# Plus/minus: -8.0
#
# Buchanan & Saunders:
# Minutes: 22
# Plus/minus: -8.0
#
# All three:
# Minutes: 3
# Plus/minus: 9.0

# %%
results.to_csv("../data/results.csv", index=False)
